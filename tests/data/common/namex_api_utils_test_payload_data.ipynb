# %%
import os
from sqlalchemy import desc
import datedelta
import base64
import uuid

# %%
def factory_create_nr_payload():
    """Create NR payload"""
    payload = {
      'applicants': [
        {
          'addrLine1': '23434 River Rd',
          'addrLine2': '',
          'addrLine3': '',
          'city': 'Maple Ridge',
          'clientFirstName': '',
          'clientLastName': '',
          'contact': '',
          'countryTypeCd': 'CA',
          'declineNotificationInd': '',
          'emailAddress': None,
          'faxNumber': '111-222-3333',
          'firstName': 'jane',
          'lastName': 'doe',
          'middleName': '',
          'partyId': '',
          'phoneNumber': '250-111-2222',
          'postalCd': 'V2W 1B7',
          'stateProvinceCd': 'BC'
        }
      ],
      'names': [
        {
          'name': None,
          'designation': '',
          'choice': 1,
          'name_type_cd': None,
          'consent_words': '',
          'conflict1': '',
          'conflict1_num': ''
        }
      ],
      'natureBusinessInfo': 'sdfsdf',
      'priorityCd': 'N',
      'entity_type_cd': None,
      'request_action_cd': 'NEW',
      'stateCd': 'DRAFT',
      'english': True,
      'nameFlag': False,
      'submit_count': 0,
      'corpNum': '',
      'homeJurisNum': '',
      'tradeMark': '',
      'xproJurisdiction': '',
      'additionalInfo': '*** New Request ***'
    }
    return payload

# %%
def factory_create_nr_payment_payload():
    """Create NR payload"""
    payload = {
      'filingInfo': {
        'filingTypes': [
          {
            'filingTypeCode': None,
            'priority': False
          }
        ]
      },
      'headers': {
        'folioNumber': ''
      }
    }

    return payload

# %%
def factory_update_nr_name_payload():
    payload = {
      'choice': None,
      'comment': None,
      'conflict1': '',
      'conflict1_num': '',
      'conflict2': '',
      'conflict2_num': '',
      'conflict3': '',
      'conflict3_num': '',
      'consumptionDate': None,
      'corpNum': None,
      'decision_text': '',
      'designation': None,
      'id': None,
      'name': None,
      'name_type_cd': None,
      'state': None
    } 
    return payload
