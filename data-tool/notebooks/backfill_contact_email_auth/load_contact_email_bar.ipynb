# %% [markdown]
# # BACKFILL Contact Email for BAR Corps
#
# ## Overview
# BAR backfill contact email
# - Get identifier list per batch and group
# - For Each identifier make POST to API to set contact

# %%
# %pip install pandas requests
# %pip install sqlalchemy>=2.0
# %pip install psycopg2-binary
# %pip install python-dotenv

# %% [markdown]
# # Load Configurations

# %%
import os
from datetime import datetime
from typing import Optional

import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError, OperationalError
from sqlalchemy.engine import Engine
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
print("Environment variables loaded successfully.")

# %% [markdown]
# ## Database Configuration
#
# Configure connections to:
# - **colin_extract**: Target database for `bar_corps` table
# - **auth**: Source Auth API

# %%
DATABASE_CONFIG = {
    'colin_extract': {
        'username': os.getenv("DATABASE_COLIN_EXTRACT_USERNAME"),
        'password': os.getenv("DATABASE_COLIN_EXTRACT_PASSWORD"),
        'host': os.getenv("DATABASE_COLIN_EXTRACT_HOST"),
        'port': os.getenv("DATABASE_COLIN_EXTRACT_PORT"),
        'name': os.getenv("DATABASE_COLIN_EXTRACT_NAME")
    },
    'auth': {
        'username': os.getenv("DATABASE_AUTH_USERNAME"),
        'password': os.getenv("DATABASE_AUTH_PASSWORD"),
        'host': os.getenv("DATABASE_AUTH_HOST"),
        'port': os.getenv("DATABASE_AUTH_PORT"),
        'name': os.getenv("DATABASE_AUTH_NAME")
    },
}

# Build connection URIs
for db_key, db_config in DATABASE_CONFIG.items():
    # Validate config
    missing_keys = [k for k, v in db_config.items() if v is None]
    if missing_keys:
        print(f"{db_key.upper()}: Missing environment variables for: {missing_keys}")

    # Build PostgreSQL URI
    uri = f"postgresql://{db_config['username']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['name']}"
    DATABASE_CONFIG[db_key] = {'uri': uri}

    print("Database configurations built successfully.")

AUTH_SVC_URL = os.getenv("AUTH_SVC_URL")
ACCOUNT_SVC_AUTH_URL = os.getenv("ACCOUNT_SVC_AUTH_URL")
ACCOUNT_SVC_CLIENT_ID = os.getenv("ACCOUNT_SVC_CLIENT_ID")
ACCOUNT_SVC_CLIENT_SECRET = os.getenv("ACCOUNT_SVC_CLIENT_SECRET")
ACCOUNT_SVC_ENTITY_URL = os.getenv("ACCOUNT_SVC_ENTITY_URL")

MIG_BATCH_ID = os.getenv("MIG_BATCH_ID")
ENVIRONMENTS = os.getenv("ENVIRONMENTS")
print("Service URLs and credentials loaded successfully.")

# %% [markdown]
# ## Get Identifier for Batch and Group

# %%
engines = {}

for db_key, config in DATABASE_CONFIG.items():
    try:
        print(f"Creating engine for {db_key.upper()}...")
        engine = create_engine(config['uri'])

        # Test connection
        with engine.connect() as conn:
            conn.execute(text("SELECT 1"))

        engines[db_key] = engine
        print(f"✓ {db_key.upper()} database engine created and tested successfully.")

    except OperationalError as e:
        print(f"✗ {db_key.upper()} database connection failed: {e}")
        raise
    except SQLAlchemyError as e:
        print(f"✗ {db_key.upper()} database engine creation failed: {e}")
        raise
    except Exception as e:
        print(f"✗ {db_key.upper()} unexpected error: {e}")
        raise

print("="*50)
print("All database engines ready for use.")
print("="*50)

# %%
IDENTIFIERS_QUERY = """
SELECT corp_num
FROM corp_processing cp
WHERE processed_status = 'COMPLETED'
AND mig_batch_id = :mig_batch_id
AND environment = :environment
-- LIMIT 1
"""
def query_identifiers(engine: Engine, mig_batch_id: int, environment: str) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(IDENTIFIERS_QUERY), {"mig_batch_id": mig_batch_id, "environment": environment})
            identifiers_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried identifiers. Total records: {len(identifiers_df)}")
        return identifiers_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying identifiers: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying identifiers: {e}")
        raise

identifier = query_identifiers(engines['colin_extract'], MIG_BATCH_ID, ENVIRONMENTS)
print(identifier.head())
print(f"Total identifiers retrieved: {len(identifier)}")
identifiers_from_batch_mig = identifier['corp_num'].tolist()
identifiers = identifiers_from_batch_mig
print(f"Identifiers list created with {len(identifiers)} entries.")

# %%
def get_auth_token() -> Optional[str]:
    import requests

    try:
        response = requests.post(
            ACCOUNT_SVC_AUTH_URL,
            data={
                'client_id': ACCOUNT_SVC_CLIENT_ID,
                'client_secret': ACCOUNT_SVC_CLIENT_SECRET,
                'grant_type': 'client_credentials'
            }
        )
        response.raise_for_status()
        token = response.json().get('access_token')
        if token:
            print("✓ Successfully obtained auth token.")
            return token
        else:
            print("✗ Auth token not found in response.")
            return None
    except requests.RequestException as e:
        print(f"✗ Error obtaining auth token: {e}")
        return None
auth_token = get_auth_token()
print(f"Auth token: {auth_token[:10]}...")

# %% [markdown]
# ## Entity Update

# %%
AUTH_ENTRIES_WITHOUT_ENTITIES_QUERY = """
SELECT business_identifier
FROM unnest(CAST(:identifiers AS text[])) AS business_identifier
EXCEPT
SELECT e.business_identifier
FROM entities e
WHERE e.business_identifier = ANY(:identifiers)
"""

def query_identifiers_without_entities(engine: Engine, identifiers: list) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(AUTH_ENTRIES_WITHOUT_ENTITIES_QUERY), {"identifiers": identifiers})
            no_entity_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried identifiers without entities. Total records: {len(no_entity_df)}")
        return no_entity_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying identifiers without entities: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying identifiers without entities: {e}")
        raise

identifiers_before_filtering = len(identifiers)
identifiers_without_entities_df = query_identifiers_without_entities(engines['auth'], identifiers)
identifiers_without_entities = identifiers_without_entities_df['business_identifier'].tolist()
print(f"Number of Identifiers without entity: {len(identifiers_without_entities_df)} out of {identifiers_before_filtering}")
print(f"Identifiers without entity: {identifiers_without_entities_df}")

# %%
ENTITY_DETAIL_QUERY = """
SELECT 
    c.corp_num as identifier,
    c.corp_type_cd as corp_type_code,
    cn.corp_name AS name
FROM corporation c
LEFT JOIN corp_name cn
    ON cn.corp_num = c.corp_num
    AND cn.end_event_id IS NULL
    AND cn.corp_name_typ_cd IN ('CO', 'NB')
WHERE c.corp_num = ANY(:identifiers_without_entities)
"""
def query_entity_list(engine: Engine, identifiers_without_entities: list) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(ENTITY_DETAIL_QUERY), {'identifiers_without_entities': identifiers_without_entities})
            entity_details_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried email list. Total records: {len(entity_details_df)}")
        return entity_details_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying entities details list: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying entities details list: {e}")
        raise

entity_details_list = query_entity_list(engines['colin_extract'], identifiers_without_entities)
print(entity_details_list.head())

# %%
def create_entities_auth(entity_list: pd.DataFrame) -> tuple[int, int]:
    """
    Create Auth entities for identifiers missing from entities table.
    """
    import requests
    

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {auth_token}"
    }

    success_count = failure_count = 0
    for _, row in entity_list.iterrows():
        identifier, name , corp_type_cd = row['identifier'], row['name'], row['corp_type_code']
        body = {
            "name": name,
            "corpTypeCode": corp_type_cd,
            "businessIdentifier": identifier
        }
        print(f"Creating entity for identifier: {identifier} with name: {name} corp_type_cd: {corp_type_cd}, {body}")
        try:
            response = requests.post(f"{ACCOUNT_SVC_ENTITY_URL}", json=body, headers=headers)
            response.raise_for_status()
            print(f"✓ Successfully Created entity for {identifier}")
            success_count += 1
        except requests.exceptions.HTTPError as http_err:
            print(f"✗ HTTP error occurred while updating {identifier}: {http_err}")
            failure_count += 1
        except Exception as err:
            print(f"✗ Unexpected error occurred while updating {identifier}: {err}")
            failure_count += 1
        
    return success_count, failure_count


success_count, failure_count = create_entities_auth(entity_details_list)
print(f"Update results - Success: {success_count}, Failure: {failure_count}")

# %% [markdown]
# ## Contacts Update

# %%
AUTH_ENTRIES_WITHOUT_EMAIL_QUERY = """
SELECT e.business_identifier
FROM entities e
WHERE e.business_identifier = ANY(:identifiers)
AND NOT EXISTS (
    SELECT 1
    FROM contact_links cl
    JOIN contacts c ON cl.contact_id = c.id
    WHERE cl.entity_id = e.id
    AND c.email IS NOT NULL
    )
"""

def query_identifiers_without_email(engine: Engine, identifiers: list) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(AUTH_ENTRIES_WITHOUT_EMAIL_QUERY), {"identifiers": identifiers})
            no_email_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried identifiers without email. Total records: {len(no_email_df)}")
        return no_email_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying identifiers without email: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying identifiers without email: {e}")
        raise

identifiers_before_filtering = len(identifiers)
identifiers_without_email_df = query_identifiers_without_email(engines['auth'], identifiers)
identifiers_without_email = identifiers_without_email_df['business_identifier'].tolist()
print(f"Number of Identifiers without email: {len(identifiers_without_email)} out of {identifiers_before_filtering}")
print(f"Identifiers without email: {identifiers_without_email}")

# %%
EMAIL_LIST_QUERY = """
SELECT 
c.corp_num as identifier,
c.admin_email as email
FROM corporation c
WHERE 1 = 1
and c.corp_num = ANY(:identifiers)
"""
def query_email_list(engine: Engine, identifiers: list) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(EMAIL_LIST_QUERY), {'identifiers': identifiers_without_email})
            email_list_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried email list. Total records: {len(email_list_df)}")
        return email_list_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying email list: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying email list: {e}")
        raise

email_list = query_email_list(engines['colin_extract'], identifiers)
print(email_list.head())

# %%
def update_email_contact_auth(email_list: pd.DataFrame) -> tuple[int, int]:
    """
    Update the contact email for a given identifier using the Auth API.

    Args:
        email_list (list): A list of dictionaries containing 'identifier' and 'email' keys.
    Returns:
        tuple[int, int]: A tuple containing the count of successful updates and failed updates.
    """
    import requests
    

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {auth_token}"
    }

    success_count = failure_count = 0
    for _, row in email_list.iterrows():
        identifier, email = row['identifier'], row['email']
        print(f"Updating contact email for identifier: {identifier} with email: {email}")
        try:
            response = requests.post(f"{ACCOUNT_SVC_ENTITY_URL}/{identifier}/contacts", json={"email": email_list[email_list['identifier'] == identifier]['email'].values[0] if not email_list.empty else None}, headers=headers)
            response.raise_for_status()
            print(f"✓ Successfully updated contact email for {identifier}")
            success_count += 1
        except requests.exceptions.HTTPError as http_err:
            print(f"✗ HTTP error occurred while updating {identifier}: {http_err}")
            failure_count += 1
        except Exception as err:
            print(f"✗ Unexpected error occurred while updating {identifier}: {err}")
            failure_count += 1
        
    return success_count, failure_count


success_count, failure_count = update_email_contact_auth(email_list)
print(f"Update results - Success: {success_count}, Failure: {failure_count}")

# %% [markdown]
# ## Affiliation Invitations

# %%
AUTH_ENTRIES_WITHOUT_AFFILIATION_INVITATION_QUERY = """
SELECT 
e.business_identifier as identifier
FROM entities e
WHERE 1 = 1
and e.business_identifier = ANY(:identifiers)
AND NOT EXISTS (
    SELECT 1
    FROM affiliation_invitations ai
    WHERE ai.entity_id = e.id
    )
"""

def query_identifiers_without_affiliation_invitation(engine: Engine, identifiers: list) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(AUTH_ENTRIES_WITHOUT_AFFILIATION_INVITATION_QUERY), {"identifiers": identifiers})
            no_invite_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried identifiers without invitation. Total records: {len(no_invite_df)}")
        return no_invite_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying identifiers without invite: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying identifiers without invite: {e}")
        raise

identifiers_before_invite_check = len(identifiers)
identifiers_without_affiliation_invitation_df = query_identifiers_without_affiliation_invitation(engines['auth'], identifiers)
identifiers_without_affiliation_invitation = identifiers_without_affiliation_invitation_df['identifier'].tolist()
print(f"Number of Identifiers without affiliation invitation: {len(identifiers_without_affiliation_invitation_df)} out of {identifiers_before_invite_check}")
print(f"Identifiers without invite: {identifiers_without_affiliation_invitation}")

# %%
def send_unaffiliation_email_auth(identifier_list: pd.DataFrame) -> tuple[int, int]:
    """
    Create Auth entities for identifiers missing from entities table.
    """
    import requests
    

    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {auth_token}"
    }

    success_count = failure_count = 0
    for _, row in identifier_list.iterrows():
        identifier = row['identifier']
        print(f"Sending Unaffiliated email for identifier: {identifier}")
        try:
            response = requests.post(f"{AUTH_SVC_URL}/affiliationInvitations/unaffiliated/{identifier}", headers=headers)
            response.raise_for_status()
            print(f"✓ Successfully sent unaffiliated email for {identifier}")
            success_count += 1
        except requests.exceptions.HTTPError as http_err:
            print(f"✗ HTTP error occurred while updating {identifier}: {http_err}")
            failure_count += 1
        except Exception as err:
            print(f"✗ Unexpected error occurred while updating {identifier}: {err}")
            failure_count += 1
        
    return success_count, failure_count


success_count, failure_count = send_unaffiliation_email_auth(identifiers_without_affiliation_invitation_df)
print(f"Update results - Success: {success_count}, Failure: {failure_count}")

# %% [markdown]
# ## Query Pending Failed Identifiers

# %%
CORP_PROCESSING_STATUS_QUERY = """
SELECT corp_num
FROM corp_processing cp
WHERE processed_status = 'FAILED'
AND mig_batch_id = :mig_batch_id
AND environment = :environment
-- LIMIT 1
"""

def query_failed_identifiers(engine: Engine, mig_batch_id: int, environment: str) -> pd.DataFrame:
    try:
        with engine.connect() as conn:
            result = conn.execute(text(CORP_PROCESSING_STATUS_QUERY), {"mig_batch_id": mig_batch_id, "environment": environment})
            failed_identifiers_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        print(f"✓ Successfully queried identifiers. Total records: {len(failed_identifiers_df)}")
        return failed_identifiers_df
    except SQLAlchemyError as e:
        print(f"✗ Error querying identifiers: {e}")
        raise
    except Exception as e:
        print(f"✗ Unexpected error querying identifiers: {e}")
        raise

failed_identifier = query_failed_identifiers(engines['colin_extract'], MIG_BATCH_ID, ENVIRONMENTS)
print(failed_identifier.head())
print(f"Total Failed identifiers retrieved: {len(failed_identifier)}")
identifiers_from_batch_mig = failed_identifier['corp_num'].tolist()
failed_identifiers = identifiers_from_batch_mig
print(f"Identifiers list created with {len(failed_identifiers)} entries.")

# %%
from IPython.display import display

def build_failed_identifier_report(failed_ids: list[str]) -> pd.DataFrame:
    if not failed_ids:
        print("No failed identifiers in corp processing....")
        return pd.DataFrame(
            columns=[
                "identifier",
                "no_entity",
                "no_contact",
                "no_invitation"
            ]
        )
    report = pd.DataFrame({"identifier": failed_ids})
    no_entity = set(
        query_identifiers_without_entities(engines['auth'], failed_ids)["business_identifier"]
    )
    no_contact = set(
        query_identifiers_without_email(engines['auth'], failed_ids)["business_identifier"]
    )
    no_invitation = set(
        query_identifiers_without_affiliation_invitation(engines['auth'], failed_ids)["identifier"]
    )

    report["no_entity"] = report["identifier"].isin(no_entity)
    report["no_contact"] = report["identifier"].isin(no_entity | no_contact)
    report["no_invitation"] = report["identifier"].isin(no_entity | no_invitation)
    return report

failed_report = build_failed_identifier_report(failed_identifiers)
print(f"Failed identifier verification rows: {len(failed_report)}")
display(failed_report)
